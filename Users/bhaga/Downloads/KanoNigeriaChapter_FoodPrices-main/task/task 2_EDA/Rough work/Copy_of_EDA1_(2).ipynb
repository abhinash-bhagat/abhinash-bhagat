# %% [markdown]
# # Import necessary libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv('https://github.com/armaf002/Food-price/raw/main/preprocessed-data.csv')
df.head()
# Out:
#          date    State Local_Government  Market_Name  latitude  longitude  \
# 0  2002-01-15  Katsina            Jibia  Jibia (CBM)     13.08       7.24
# 1  2002-01-15  Katsina            Jibia  Jibia (CBM)     13.08       7.24
# 2  2002-01-15  Katsina            Jibia  Jibia (CBM)     13.08       7.24
# 3  2002-01-15  Katsina            Jibia  Jibia (CBM)     13.08       7.24
# 4  2002-01-15  Katsina            Jibia  Jibia (CBM)     13.08       7.24
#
#              category        commodity unit priceflag  pricetype currency  \
# 0  cereals and tubers            Maize  1KG    actual  Wholesale      NGN
# 1  cereals and tubers           Millet  1KG    actual  Wholesale      NGN
# 2  cereals and tubers  Rice (imported)  1KG    actual  Wholesale      NGN
# 3  cereals and tubers          Sorghum  1KG    actual  Wholesale      NGN
# 4     pulses and nuts    Beans (niebe)  1KG    actual  Wholesale      NGN
#
#     price  usdprice  year    month      season  Inflation
# ...

# %%
#check the last rows of the dataset
df.tail()
# Out:
#              date    State Local_Government   Market_Name  latitude  \
# 64216  2023-01-15  Zamfara     Kaura Namoda  Kaura Namoda  12.59519
# 64217  2023-01-15  Zamfara     Kaura Namoda  Kaura Namoda  12.59519
# 64218  2023-01-15  Zamfara     Kaura Namoda  Kaura Namoda  12.59519
# 64219  2023-01-15  Zamfara     Kaura Namoda  Kaura Namoda  12.59519
# 64220  2023-01-15  Zamfara     Kaura Namoda  Kaura Namoda  12.59519
#
#        longitude         category             commodity unit  priceflag  \
# 64216    6.58635  pulses and nuts       Cowpeas (brown)  1KG  aggregate
# 64217    6.58635  pulses and nuts       Cowpeas (brown)  1KG  aggregate
# 64218    6.58635  pulses and nuts       Cowpeas (white)  1KG  aggregate
# 64219    6.58635  pulses and nuts       Cowpeas (white)  1KG  aggregate
# 64220    6.58635  pulses and nuts  Groundnuts (shelled)  1KG  aggregate
#
#        pricetype currency   price  usdprice  year    month      season  \
# ...

# %% [markdown]
#   # EDA

# %%
# Check the data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64221 entries, 0 to 64220
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              64221 non-null  object
#  1   State             64221 non-null  object
#  2   Local_Government  64221 non-null  object
#  3   Market_Name       64221 non-null  object
#  4   latitude          64221 non-null  float64
#  5   longitude         64221 non-null  float64
#  6   category          64221 non-null  object
#  7   commodity         64221 non-null  object
#  8   unit              64221 non-null  object
#  9   priceflag         64221 non-null  object
#  10  pricetype         64221 non-null  object
#  11  currency          64221 non-null  object
#  12  price             64221 non-null  float64
#  13  usdprice          64221 non-null  float64
#  14  year              64221 non-null  int64
#  15  month             64221 non-null  object
# ...

# %%
# Determine the number of rows and columns in the dataset
df.shape
# Out:
# (64221, 18)

# %%
# Check if there are any missing values in the dataset
df.isnull().sum()
# Out:
# date                0
# State               0
# Local_Government    0
# Market_Name         0
# latitude            0
# longitude           0
# category            0
# commodity           0
# unit                0
# priceflag           0
# pricetype           0
# currency            0
# price               0
# usdprice            0
# year                0
# month               0
# season              0
# Inflation           0
# dtype: int64

# %%
# Check if there are any duplicate
df.duplicated().sum()
# Out:
# 0

# %%
# Get summary statistics for numerical columns
df.describe()
# Out:
#            latitude     longitude          price      usdprice          year  \
# count  64221.000000  64221.000000   64221.000000  64221.000000  64221.000000
# mean      11.403807     10.242149     715.880441     35.868101   2018.732938
# std        1.697178      2.948587    4901.473445    367.334531      2.969550
# min        5.147640      3.401897       0.810000      0.002300   2002.000000
# 25%       11.280160      8.429120      46.428571      0.602000   2017.000000
# 50%       11.831100     11.166670     166.665000      1.306800   2019.000000
# 75%       12.362300     13.092646     358.000000     28.511800   2021.000000
# max       13.645000     13.264360  138000.000000  28662.419400   2023.000000
#
#           Inflation
# count  64221.000000
# mean      14.431006
# std        3.098797
# min        5.388008
# 25%       12.095107
# 50%       13.246023
# 75%       16.952846
# max       19.160000

# %%
# Get the corellation between the numerical data
df.corr()
# Out:
#            latitude  longitude     price  usdprice      year  Inflation
# latitude   1.000000   0.434396 -0.025368 -0.036598 -0.076376  -0.029596
# longitude  0.434396   1.000000 -0.004234 -0.045452  0.154937   0.061844
# price     -0.025368  -0.004234  1.000000  0.023319  0.077559   0.082633
# usdprice  -0.036598  -0.045452  0.023319  1.000000 -0.033059   0.035062
# year      -0.076376   0.154937  0.077559 -0.033059  1.000000   0.529896
# Inflation -0.029596   0.061844  0.082633  0.035062  0.529896   1.000000

# %% [markdown]
# ## Geographical Distribution Analysis

# %%
'''
# scattermapbox plot using Plotly Express
fig = px.scatter_mapbox(df, lat="latitude", lon="longitude", hover_name="commodity", hover_data=["price"])
fig.update_layout(
    title="Geographical Distribution of Commodity Prices",
    mapbox_style="carto-positron",
    mapbox_zoom=7,  # Adjust the zoom level to your preference
    mapbox_center={"lat": df['latitude'].mean(), "lon": df['longitude'].mean()},
    margin={"r": 0, "t": 0, "l": 0, "b": 0}  # Set margins to zero for better clarity
)

# Display the interactive map in the Jupyter Notebook
fig.show()
'''
# Out:
# '\n# scattermapbox plot using Plotly Express\nfig = px.scatter_mapbox(df, lat="latitude", lon="longitude", hover_name="commodity", hover_data=["price"])\nfig.update_layout(\n    title="Geographical Distribution of Commodity Prices",\n    mapbox_style="carto-positron",\n    mapbox_zoom=7,  # Adjust the zoom level to your preference\n    mapbox_center={"lat": df[\'latitude\'].mean(), "lon": df[\'longitude\'].mean()},\n    margin={"r": 0, "t": 0, "l": 0, "b": 0}  # Set margins to zero for better clarity\n)\n\n# Display the interactive map in the Jupyter Notebook\nfig.show()\n'

# %% [markdown]
# Upon plotting the data points on an interactive map, it becomes evident that the majority of the data was collected from the northern part of the region. The central point of the data is concentrated in the northern region, indicating that this area has a higher density of recorded commodity prices. The latitude and longitude values of the data points confirm this concentration.
