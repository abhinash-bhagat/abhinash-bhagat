# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %% [markdown]
# # ***`Exploring descriptive Stastics `***

# %%
df=pd.read_csv("/content/FOOD price data ,(cleaned,removed duplicates).csv")
df
# Out:
# <ipython-input-3-9d7e72527f55>:1: DtypeWarning: Columns (0,1,2,3,4,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/FOOD price data ,(cleaned,removed duplicates).csv")
#         Country Region Market           Product        Date      Open  \
# 0       Nigeria   Abia    Aba  food_price_index  01-10-2023      2.04
# 1       Nigeria   Abia    Aba             maize  01-10-2023  27243.87
# 2       Nigeria   Abia    Aba           sorghum  01-10-2023  27372.27
# 3       Nigeria   Abia    Aba              gari  01-10-2023  24293.85
# 4       Nigeria   Abia    Aba              rice  01-10-2023  33636.83
# ...         ...    ...    ...               ...         ...       ...
# 119444      NaN    NaN    NaN               NaN         NaN       NaN
# 119445      NaN    NaN    NaN               NaN         NaN       NaN
# 119446      NaN    NaN    NaN               NaN         NaN       NaN
# ...

# %%
df.describe(include="all")
# Out:
#         Country Region Market           Product        Date          Open  \
# count     65448  65448  65448             65448       65448  65448.000000
# unique        1     14     36                 9         202           NaN
# top     Nigeria   Yobe    Aba  food_price_index  01-10-2023           NaN
# freq      65448  21816   1818              7272         324           NaN
# mean        NaN    NaN    NaN               NaN         NaN  13729.062743
# std         NaN    NaN    NaN               NaN         NaN  10502.690938
# min         NaN    NaN    NaN               NaN         NaN      0.410000
# 25%         NaN    NaN    NaN               NaN         NaN   6388.210000
# 50%         NaN    NaN    NaN               NaN         NaN  11513.590000
# 75%         NaN    NaN    NaN               NaN         NaN  19338.290000
# max         NaN    NaN    NaN               NaN         NaN  91766.990000
#
#                 High           Low         Close Currency
# ...

# %%
df.isnull()
# Out:
#         Country  Region  Market  Product   Date   Open   High    Low  Close  \
# 0         False   False   False    False  False  False  False  False  False
# 1         False   False   False    False  False  False  False  False  False
# 2         False   False   False    False  False  False  False  False  False
# 3         False   False   False    False  False  False  False  False  False
# 4         False   False   False    False  False  False  False  False  False
# ...         ...     ...     ...      ...    ...    ...    ...    ...    ...
# 119444     True    True    True     True   True   True   True   True   True
# 119445     True    True    True     True   True   True   True   True   True
# 119446     True    True    True     True   True   True   True   True   True
# 119447     True    True    True     True   True   True   True   True   True
# 119448     True    True    True     True   True   True   True   True   True
#
#         Currency
# 0          False
# 1          False
# ...

# %%
df.isnull().sum()
# Out:
# Country     54001
# Region      54001
# Market      54001
# Product     54001
# Date        54001
# Open        54001
# High        54001
# Low         54001
# Close       54001
# Currency    54001
# dtype: int64

# %%
df=df.dropna(axis=0)

# %%
df.describe(include="all")
# Out:
#         Country Region Market           Product        Date          Open  \
# count     65448  65448  65448             65448       65448  65448.000000
# unique        1     14     36                 9         202           NaN
# top     Nigeria   Yobe    Aba  food_price_index  01-10-2023           NaN
# freq      65448  21816   1818              7272         324           NaN
# mean        NaN    NaN    NaN               NaN         NaN  13729.062743
# std         NaN    NaN    NaN               NaN         NaN  10502.690938
# min         NaN    NaN    NaN               NaN         NaN      0.410000
# 25%         NaN    NaN    NaN               NaN         NaN   6388.210000
# 50%         NaN    NaN    NaN               NaN         NaN  11513.590000
# 75%         NaN    NaN    NaN               NaN         NaN  19338.290000
# max         NaN    NaN    NaN               NaN         NaN  91766.990000
#
#                 High           Low         Close Currency
# ...

# %%
df.isnull().sum()
# Out:
# Country     0
# Region      0
# Market      0
# Product     0
# Date        0
# Open        0
# High        0
# Low         0
# Close       0
# Currency    0
# dtype: int64

# %%
sns.distplot(df['Close'])
# Out:
# <ipython-input-24-400ee7bb7740>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Close'])
# <Axes: xlabel='Close', ylabel='Density'>

# %%
q=df['Close'].quantile(0.99)
data_1=df[df['Close']<q]

# %%
sns.distplot(df['Open'])
# Out:
# <ipython-input-33-e567a83812a5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Open'])
# <Axes: xlabel='Open', ylabel='Density'>

# %%
q = data_1['Open'].quantile(0.99)
data_2=data_1[data_1['Open']<q]

# %%
data_cleaned=data_2.reset_index(drop=True)
data_cleaned.describe(include="all")
# Out:
#         Country Region    Market           Product        Date          Open  \
# count     64145  64145     64145             64145       64145  64145.000000
# unique        1     14        36                 9         202           NaN
# top     Nigeria   Yobe  Damaturu  food_price_index  01-05-2015           NaN
# freq      64145  21628      1806              7272         324           NaN
# mean        NaN    NaN       NaN               NaN         NaN  12972.526470
# std         NaN    NaN       NaN               NaN         NaN   9083.919038
# min         NaN    NaN       NaN               NaN         NaN      0.410000
# 25%         NaN    NaN       NaN               NaN         NaN   6268.500000
# 50%         NaN    NaN       NaN               NaN         NaN  11340.740000
# 75%         NaN    NaN       NaN               NaN         NaN  18599.400000
# max         NaN    NaN       NaN               NaN         NaN  42727.720000
#
# ...
